# %% [markdown]
# # 2.a)Linear Model Fitting

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = np.array([[1, 2], [2, 4], [3, 6], [4, 8]])
# y = 2 * x_0 + 3 * x_1 + 4* x_2 +5
y = np.dot(X, np.array([2, 3])) + 5
reg = LinearRegression().fit(X, y)
reg.score(X, y)
# Out:
# 1.0

# %%
reg.coef_
# Out:
# array([1.6, 3.2])

# %%
reg.intercept_
# Out:
# 5.0

# %% [markdown]
# # 2.b) Normal Equations

# %%
X = np.array([[1, 2], [2, 4],[3,6],[4,8]])
Y = np.array([[2],[3],[4],[5]])

# %%
xt=X.transpose()
m=np.matmul(xt,X)
y=np.matmul(xt,Y)

# %%
np.linalg.inv(m)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-18-83af191aaacb> in <module>()
# ----> 1 np.linalg.inv(m)
#
# d:\geek_stuff\python3.6\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     530     signature = 'D->D' if isComplexType(t) else 'd->d'
#     531     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 532     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     533     return wrap(ainv.astype(result_t, copy=False))
#     534
#
# d:\geek_stuff\python3.6\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %% [markdown]
# # The matrix Xt*X is non-invertible
# # The matrix is non-invertible because the 2nd column is linearly dependant on the first column. Scikit learn solves the regression problem because it uses LU decomposition to calculate the inverse.
