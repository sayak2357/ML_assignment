# %%
f=open("iris.csv")
dataset=[]

# %%
for j in f:
    print(j)
    data=j.split(",")
    t0=float(data[0])
    t1=float(data[1])
    t2=int(data[2])
    dataset.append([t0,t1,t2])
# Out:
# 5.1,0.2,0
#
# 4.9,0.2,0
#
# 4.7,0.2,0
#
# 4.6,0.2,0
#
# 5,0.2,0
#
# 5.4,0.4,0
#
# 4.6,0.3,0
#
# 5,0.2,0
#
# 4.4,0.2,0
#
# 4.9,0.1,0
#
# 5.4,0.2,0
#
# 4.8,0.2,0
#
# 4.8,0.1,0
#
# 4.3,0.1,0
#
# 5.8,0.2,0
#
# 5.7,0.4,0
#
# 5.4,0.4,0
#
# 5.1,0.3,0
#
# 5.7,0.3,0
#
# 5.1,0.3,0
#
# 5.4,0.2,0
#
# 5.1,0.4,0
#
# 4.6,0.2,0
#
# 5.1,0.5,0
#
# 4.8,0.2,0
#
# 5,0.2,0
#
# 5,0.4,0
#
# 5.2,0.2,0
#
# 5.2,0.2,0
#
# 4.7,0.2,0
#
# 4.8,0.2,0
#
# 5.4,0.4,0
#
# 5.2,0.1,0
#
# 5.5,0.2,0
#
# 4.9,0.1,0
#
# 5,0.2,0
#
# 5.5,0.2,0
#
# 4.9,0.1,0
#
# 4.4,0.2,0
#
# 5.1,0.2,0
#
# 5,0.3,0
#
# 4.5,0.3,0
#
# 4.4,0.2,0
#
# 5,0.6,0
#
# 5.1,0.4,0
#
# 4.8,0.3,0
#
# 5.1,0.2,0
#
# 4.6,0.2,0
#
# 5.3,0.2,0
#
# 5,0.2,0
#
# 7,1.4,1
#
# 6.4,1.5,1
#
# 6.9,1.5,1
#
# 5.5,1.3,1
#
# 6.5,1.5,1
#
# 5.7,1.3,1
#
# 6.3,1.6,1
#
# 4.9,1,1
#
# 6.6,1.3,1
#
# 5.2,1.4,1
#
# 5,1,1
#
# 5.9,1.5,1
#
# 6,1,1
#
# 6.1,1.4,1
#
# 5.6,1.3,1
#
# 6.7,1.4,1
#
# 5.6,1.5,1
#
# 5.8,1,1
#
# 6.2,1.5,1
#
# 5.6,1.1,1
#
# 5.9,1.8,1
#
# 6.1,1.3,1
#
# 6.3,1.5,1
#
# 6.1,1.2,1
#
# 6.4,1.3,1
#
# 6.6,1.4,1
#
# 6.8,1.4,1
#
# 6.7,1.7,1
#
# 6,1.5,1
#
# 5.7,1,1
#
# 5.5,1.1,1
#
# 5.5,1,1
#
# 5.8,1.2,1
#
# 6,1.6,1
#
# 5.4,1.5,1
#
# 6,1.6,1
#
# 6.7,1.5,1
#
# 6.3,1.3,1
#
# 5.6,1.3,1
#
# 5.5,1.3,1
#
# 5.5,1.2,1
#
# 6.1,1.4,1
#
# 5.8,1.2,1
#
# 5,1,1
#
# 5.6,1.3,1
#
# 5.7,1.2,1
#
# 5.7,1.3,1
#
# 6.2,1.3,1
#
# 5.1,1.1,1
#
# 5.7,1.3,1
#
# 6.3,2.5,1
#
# 5.8,1.9,1
#
# 7.1,2.1,1
#
# 6.3,1.8,1
#
# 6.5,2.2,1
#
# 7.6,2.1,1
#
# 4.9,1.7,1
#
# 7.3,1.8,1
#
# 6.7,1.8,1
#
# 7.2,2.5,1
#
# 6.5,2,1
#
# 6.4,1.9,1
#
# 6.8,2.1,1
#
# 5.7,2,1
#
# 5.8,2.4,1
#
# 6.4,2.3,1
#
# 6.5,1.8,1
#
# 7.7,2.2,1
#
# 7.7,2.3,1
#
# 6,1.5,1
#
# 6.9,2.3,1
#
# 5.6,2,1
#
# 7.7,2,1
#
# 6.3,1.8,1
#
# 6.7,2.1,1
#
# 7.2,1.8,1
#
# 6.2,1.8,1
#
# 6.1,1.8,1
#
# 6.4,2.1,1
#
# 7.2,1.6,1
#
# 7.4,1.9,1
#
# 7.9,2,1
#
# 6.4,2.2,1
#
# 6.3,1.5,1
#
# 6.1,1.4,1
#
# 7.7,2.3,1
#
# 6.3,2.4,1
#
# 6.4,1.8,1
#
# 6,1.8,1
#
# 6.9,2.1,1
#
# 6.7,2.4,1
#
# 6.9,2.3,1
#
# 5.8,1.9,1
#
# 6.8,2.3,1
#
# 6.7,2.5,1
#
# 6.7,2.3,1
#
# 6.3,1.9,1
#
# 6.5,2,1
#
# 6.2,2.3,1
#
# 5.9,1.8,1

# %%
from math import exp
 
# Make a prediction with coefficients
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	return 1.0 / (1.0 + exp(-yhat))
 
# Estimate logistic regression coefficients using stochastic gradient descent
def coefficients_sgd(train, l_rate, n_epoch):
	coef = [0.0 for i in range(len(train[0]))]
	for epoch in range(n_epoch):
		sum_error = 0
		for row in train:
			yhat = predict(row, coef)
			error = row[-1] - yhat
			sum_error += error**2
			coef[0] = coef[0] + l_rate * error * yhat * (1.0 - yhat)
			for i in range(len(row)-1):
				coef[i + 1] = coef[i + 1] + l_rate * error * yhat * (1.0 - yhat) * row[i]
		print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))
	return coef
 
# Calculate coefficients
l_rate = 0.3
n_epoch = 100
coef = coefficients_sgd(dataset, l_rate, n_epoch)
print(coef)
# Out:
# >epoch=0, lrate=0.300, error=7.427
# >epoch=1, lrate=0.300, error=9.194
# >epoch=2, lrate=0.300, error=7.882
# >epoch=3, lrate=0.300, error=6.805
# >epoch=4, lrate=0.300, error=5.942
# >epoch=5, lrate=0.300, error=5.222
# >epoch=6, lrate=0.300, error=4.619
# >epoch=7, lrate=0.300, error=4.107
# >epoch=8, lrate=0.300, error=3.673
# >epoch=9, lrate=0.300, error=3.320
# >epoch=10, lrate=0.300, error=3.024
# >epoch=11, lrate=0.300, error=2.766
# >epoch=12, lrate=0.300, error=2.541
# >epoch=13, lrate=0.300, error=2.345
# >epoch=14, lrate=0.300, error=2.177
# >epoch=15, lrate=0.300, error=2.033
# >epoch=16, lrate=0.300, error=1.907
# >epoch=17, lrate=0.300, error=1.797
# >epoch=18, lrate=0.300, error=1.697
# >epoch=19, lrate=0.300, error=1.605
# >epoch=20, lrate=0.300, error=1.521
# >epoch=21, lrate=0.300, error=1.443
# >epoch=22, lrate=0.300, error=1.371
# >epoch=23, lrate=0.300, error=1.304
# >epoch=24, lrate=0.300, error=1.242
# >epoch=25, lrate=0.300, error=1.185
# >epoch=26, lrate=0.300, error=1.132
# >epoch=27, lrate=0.300, error=1.084
# >epoch=28, lrate=0.300, error=1.040
# >epoch=29, lrate=0.300, error=0.999
# >epoch=30, lrate=0.300, error=0.962
# >epoch=31, lrate=0.300, error=0.928
# >epoch=32, lrate=0.300, error=0.896
# >epoch=33, lrate=0.300, error=0.868
# >epoch=34, lrate=0.300, error=0.842
# >epoch=35, lrate=0.300, error=0.818
# >epoch=36, lrate=0.300, error=0.796
# >epoch=37, lrate=0.300, error=0.776
# >epoch=38, lrate=0.300, error=0.758
# >epoch=39, lrate=0.300, error=0.741
# >epoch=40, lrate=0.300, error=0.725
# >epoch=41, lrate=0.300, error=0.710
# >epoch=42, lrate=0.300, error=0.696
# >epoch=43, lrate=0.300, error=0.684
# >epoch=44, lrate=0.300, error=0.672
# >epoch=45, lrate=0.300, error=0.660
# >epoch=46, lrate=0.300, error=0.650
# >epoch=47, lrate=0.300, error=0.639
# >epoch=48, lrate=0.300, error=0.630
# >epoch=49, lrate=0.300, error=0.621
# >epoch=50, lrate=0.300, error=0.612
# >epoch=51, lrate=0.300, error=0.603
# >epoch=52, lrate=0.300, error=0.595
# >epoch=53, lrate=0.300, error=0.588
# >epoch=54, lrate=0.300, error=0.580
# >epoch=55, lrate=0.300, error=0.573
# >epoch=56, lrate=0.300, error=0.566
# >epoch=57, lrate=0.300, error=0.559
# >epoch=58, lrate=0.300, error=0.552
# >epoch=59, lrate=0.300, error=0.546
# >epoch=60, lrate=0.300, error=0.540
# >epoch=61, lrate=0.300, error=0.534
# >epoch=62, lrate=0.300, error=0.528
# >epoch=63, lrate=0.300, error=0.522
# >epoch=64, lrate=0.300, error=0.517
# >epoch=65, lrate=0.300, error=0.511
# >epoch=66, lrate=0.300, error=0.506
# >epoch=67, lrate=0.300, error=0.501
# >epoch=68, lrate=0.300, error=0.495
# >epoch=69, lrate=0.300, error=0.491
# >epoch=70, lrate=0.300, error=0.486
# >epoch=71, lrate=0.300, error=0.481
# >epoch=72, lrate=0.300, error=0.476
# >epoch=73, lrate=0.300, error=0.472
# >epoch=74, lrate=0.300, error=0.467
# >epoch=75, lrate=0.300, error=0.463
# >epoch=76, lrate=0.300, error=0.459
# >epoch=77, lrate=0.300, error=0.454
# >epoch=78, lrate=0.300, error=0.450
# >epoch=79, lrate=0.300, error=0.446
# >epoch=80, lrate=0.300, error=0.442
# >epoch=81, lrate=0.300, error=0.438
# >epoch=82, lrate=0.300, error=0.434
# >epoch=83, lrate=0.300, error=0.431
# >epoch=84, lrate=0.300, error=0.427
# >epoch=85, lrate=0.300, error=0.423
# >epoch=86, lrate=0.300, error=0.420
# >epoch=87, lrate=0.300, error=0.416
# >epoch=88, lrate=0.300, error=0.413
# >epoch=89, lrate=0.300, error=0.410
# >epoch=90, lrate=0.300, error=0.406
# >epoch=91, lrate=0.300, error=0.403
# >epoch=92, lrate=0.300, error=0.400
# >epoch=93, lrate=0.300, error=0.397
# >epoch=94, lrate=0.300, error=0.394
# >epoch=95, lrate=0.300, error=0.391
# >epoch=96, lrate=0.300, error=0.388
# >epoch=97, lrate=0.300, error=0.385
# >epoch=98, lrate=0.300, error=0.382
# >epoch=99, lrate=0.300, error=0.379
# [-1.7788099099513481, -0.545939194608323, 7.2628732736141135]
